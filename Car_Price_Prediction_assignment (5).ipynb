# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#mounting google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Loading data and cheking five rows 
df_car=pd.read_csv("/content/drive/MyDrive/CarPrice_Assignment.csv")
df_car.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
X=df_car.iloc[:,:-1]
y=df_car.iloc[:,-1]

# %%
X.drop(X.select_dtypes(include='object'),axis=1,inplace=True)

# %%
print(f"Shape of input ==> X :{X.shape}\nShape of output ==> Y :{y.shape} ")
# Out:
# Shape of input ==> X :(205, 15)
# Shape of output ==> Y :(205,)

# %%
X_train=X.sample(frac=0.7, replace=True, random_state=1,axis=0)
y_train=y.sample(frac=0.7, replace=True, random_state=1,axis=0)

# %%
X_test=X.sample(frac=0.3, replace=True, random_state=1,axis=0)
y_test=y.sample(frac=0.3, replace=True, random_state=1,axis=0)

# %%
print(f"shape of training data is :{X_train.shape}\nshape of training label is :{y_train.shape}\nshape of testing data is :{X_test.shape}\nshape of testing label is :{y_test.shape}")
# Out:
# shape of training data is :(144, 15)
# shape of training label is :(144,)
# shape of testing data is :(62, 15)
# shape of testing label is :(62,)

# %%
X_train=np.asarray(X_train).astype("float32")
X_test=np.asarray(X_test).astype("float32")

# %%
mean = X_train.mean(axis=0)
X_train-= mean
std = X_train.std(axis=0)
X_train/= std
X_test-= mean
X_test/= std

# %%
y_mean = y_train.mean(axis=0)
y_train-= y_mean
y_std = y_train.std(axis=0)
y_train/= y_std
y_test-= y_mean
y_test/= y_std

# %%
val_x=X_train[:50]
partial_x_train=X_train[50:]
val_y=y_train[:50]
partial_y_train=y_train[50:]

# %%
import tensorflow as tf
from keras import models,layers,optimizers,losses
network=models.Sequential()
network.add(layers.Dense(10,activation="relu" ,input_shape=(X_train.shape[1],)))
network.add(layers.Dropout(0.2))
network.add(layers.Dense(8,activation="relu"))
#network.add(layers.Dropout(0.2))
network.add(layers.Dense(6,activation="relu"))
network.add(layers.Dense(1))
network.compile(optimizer="rmsprop",loss="mse",metrics=["mae"])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                160
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 309
# Trainable params: 309
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=network.fit(partial_x_train, partial_y_train,epochs=45, batch_size=1, verbose=1,validation_data=(val_x,val_y))
# Out:
# Epoch 1/45
# 94/94 [==============================] - 1s 5ms/step - loss: 4.5334 - mae: 1.7059 - val_loss: 1.6147 - val_mae: 0.9564
# Epoch 2/45
# 94/94 [==============================] - 0s 1ms/step - loss: 0.8078 - mae: 0.7333 - val_loss: 0.9470 - val_mae: 0.7672
# Epoch 3/45
# 94/94 [==============================] - 0s 1ms/step - loss: 0.4679 - mae: 0.5366 - val_loss: 0.7159 - val_mae: 0.6826
# Epoch 4/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5042 - mae: 0.5948 - val_loss: 0.6292 - val_mae: 0.6498
# Epoch 5/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4471 - mae: 0.5570 - val_loss: 0.5453 - val_mae: 0.5998
# Epoch 6/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5022 - mae: 0.5349 - val_loss: 0.4700 - val_mae: 0.5538
# Epoch 7/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3552 - mae: 0.4564 - val_loss: 0.4711 - val_mae: 0.5540
# Epoch 8/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2539 - mae: 0.4153 - val_loss: 0.4142 - val_mae: 0.5080
# Epoch 9/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4914 - mae: 0.5016 - val_loss: 0.4006 - val_mae: 0.4859
# Epoch 10/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3059 - mae: 0.4183 - val_loss: 0.4101 - val_mae: 0.4762
# Epoch 11/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2654 - mae: 0.3994 - val_loss: 0.3815 - val_mae: 0.4591
# Epoch 12/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1327 - mae: 0.2966 - val_loss: 0.3300 - val_mae: 0.4190
# Epoch 13/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2029 - mae: 0.3106 - val_loss: 0.3279 - val_mae: 0.4083
# Epoch 14/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1859 - mae: 0.3383 - val_loss: 0.3375 - val_mae: 0.4140
# Epoch 15/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2062 - mae: 0.3180 - val_loss: 0.3356 - val_mae: 0.4106
# Epoch 16/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1733 - mae: 0.2953 - val_loss: 0.2957 - val_mae: 0.3852
# Epoch 17/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2137 - mae: 0.3296 - val_loss: 0.2883 - val_mae: 0.3829
# Epoch 18/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3921 - mae: 0.3594 - val_loss: 0.2756 - val_mae: 0.3686
# Epoch 19/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0897 - mae: 0.2239 - val_loss: 0.2749 - val_mae: 0.3677
# Epoch 20/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4107 - mae: 0.2965 - val_loss: 0.2676 - val_mae: 0.3419
# Epoch 21/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1127 - mae: 0.2312 - val_loss: 0.2402 - val_mae: 0.3349
# Epoch 22/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1949 - mae: 0.2476 - val_loss: 0.2259 - val_mae: 0.3262
# Epoch 23/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1397 - mae: 0.2467 - val_loss: 0.2065 - val_mae: 0.3080
# Epoch 24/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1699 - mae: 0.2518 - val_loss: 0.2003 - val_mae: 0.2970
# Epoch 25/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1197 - mae: 0.2443 - val_loss: 0.2193 - val_mae: 0.3193
# Epoch 26/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0814 - mae: 0.1887 - val_loss: 0.2194 - val_mae: 0.3042
# Epoch 27/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0983 - mae: 0.2322 - val_loss: 0.2252 - val_mae: 0.3107
# Epoch 28/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0917 - mae: 0.2289 - val_loss: 0.2102 - val_mae: 0.2958
# Epoch 29/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1188 - mae: 0.2337 - val_loss: 0.2144 - val_mae: 0.3144
# Epoch 30/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1481 - mae: 0.2663 - val_loss: 0.2115 - val_mae: 0.3031
# Epoch 31/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0984 - mae: 0.2261 - val_loss: 0.2091 - val_mae: 0.3101
# Epoch 32/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0737 - mae: 0.1833 - val_loss: 0.2026 - val_mae: 0.2996
# Epoch 33/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0988 - mae: 0.2174 - val_loss: 0.2185 - val_mae: 0.3103
# Epoch 34/45
# 94/94 [==============================] - 0s 1ms/step - loss: 0.1483 - mae: 0.2431 - val_loss: 0.2078 - val_mae: 0.2960
# Epoch 35/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0912 - mae: 0.1872 - val_loss: 0.2104 - val_mae: 0.3028
# Epoch 36/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0722 - mae: 0.1853 - val_loss: 0.2134 - val_mae: 0.3049
# Epoch 37/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0669 - mae: 0.1837 - val_loss: 0.2035 - val_mae: 0.2861
# Epoch 38/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1379 - mae: 0.2291 - val_loss: 0.2108 - val_mae: 0.3007
# Epoch 39/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0953 - mae: 0.2080 - val_loss: 0.1992 - val_mae: 0.2793
# Epoch 40/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0557 - mae: 0.1603 - val_loss: 0.2015 - val_mae: 0.2771
# Epoch 41/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0897 - mae: 0.1836 - val_loss: 0.1913 - val_mae: 0.2682
# Epoch 42/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1715 - mae: 0.2439 - val_loss: 0.1923 - val_mae: 0.2873
# Epoch 43/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1214 - mae: 0.2062 - val_loss: 0.1859 - val_mae: 0.2802
# Epoch 44/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1340 - mae: 0.2201 - val_loss: 0.1978 - val_mae: 0.2746
# Epoch 45/45
# 94/94 [==============================] - 0s 2ms/step - loss: 0.0997 - mae: 0.1942 - val_loss: 0.1983 - val_mae: 0.2785

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss,"go",label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
network.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1749 - mae: 0.2627
# [0.17486520111560822, 0.26269352436065674]

# %%
result_1=network.predict(X_test)
result_1[4]
# Out:
# array([0.7847265], dtype=float32)

# %%
y=result_1
y1=range(62)
x=y_test
plt.scatter(x, y1, label= "Actual price", color= "green", marker= "*", s=100)
plt.scatter(y, y1, label= "Predicted Price", color= "yellow", marker= "^", s=100)
plt.xlabel('Price')
plt.ylabel('Rows')
plt.title('Actual price vs predicted price!')
plt.legend()
plt.grid()
plt.show()
